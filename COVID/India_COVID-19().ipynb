# %%
import pandas as pd 
pd.set_option('display.max_column',34)
India_COVID=pd.read_csv(r'C:\Users\saurabh\Documents\Desktop\Data Science projects\Data For Projects\Covid-19.csv')
India_COVID=India_COVID[India_COVID['location']=='India']
India_COVID.tail(30)
# Out:
# D      Asia    India  2020-06-16     343091.0    10667.0
# 11470      IND      Asia    India  2020-06-17     354065.0    10974.0
# 11471      IND      Asia    India  2020-06-18     366946.0    12881.0
# 11472      IND      Asia    India  2020-06-19     380532.0    13586.0
# 11473      IND      Asia    India  2020-06-20     395048.0    14516.0
# 11474      IND      Asia    India  2020-06-21     410461.0    15413.0
# 11475      IND      Asia    India  2020-06-22     425282.0    14821.0
# 11476      IND      Asia    India  2020-06-23     440215.0    14933.0
# 11477      IND      Asia    India  2020-06-24     456183.0    15968.0
# 11478      IND      Asia    India  2020-06-25     473105.0    16922.0
# 11479      IND      Asia    India  2020-06-26     490401.0    17296.0
# 11480      IND      Asia    India  2020-06-27     508953.0    18552.0
# 11481      IND      Asia    India  2020-06-28     528859.0    19906.0
# 11482      IND      Asia    India  2020-06-29     548318.0    19459.0
# ...

# %%
India_COVID=India_COVID[['date','total_cases','new_cases','total_deaths','new_deaths','total_cases_per_million',	'total_tests','new_tests']]
India_COVID.set_index('date',inplace=True)

# %%
India_COVID=India_COVID[India_COVID['total_cases']!=0]
India_COVID
# Out:
#             total_cases  new_cases  total_deaths  new_deaths  \
# date
# 2020-01-30          1.0        1.0           0.0         0.0
# 2020-01-31          1.0        0.0           0.0         0.0
# 2020-02-01          1.0        0.0           0.0         0.0
# 2020-02-02          2.0        1.0           0.0         0.0
# 2020-02-03          2.0        0.0           0.0         0.0
# ...                 ...        ...           ...         ...
# 2020-06-26     490401.0    17296.0       15301.0       407.0
# 2020-06-27     508953.0    18552.0       15685.0       384.0
# 2020-06-28     528859.0    19906.0       16095.0       410.0
# 2020-06-29     548318.0    19459.0       16475.0       380.0
# 2020-06-30     566840.0    18522.0       16893.0       418.0
#
#             total_cases_per_million  total_tests  new_tests
# date
# 2020-01-30                    0.001          NaN        NaN
# 2020-01-31                    0.001          NaN        NaN
# ...

# %%
#India_COVID.to_csv(r'C:\Users\saurabh\Documents\Desktop\Data Science projects\COVID\IND_COVID-19.csv')
