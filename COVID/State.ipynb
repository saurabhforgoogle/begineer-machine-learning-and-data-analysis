# %%
import pandas as pd 
df=pd.read_csv("https://api.covid19india.org/csv/latest/state_wise.csv")
df
# Out:
#                                        State  Confirmed  Recovered  Deaths  \
# 0                                      Total    8139081    7432397  121699
# 1                                Maharashtra    1672858    1503050   43837
# 2                             Andhra Pradesh     820565     788375    6676
# 3                                  Karnataka     820398     749740   11140
# 4                                 Tamil Nadu     722011     687388   11091
# 5                              Uttar Pradesh     480082     448644    7007
# 6                                      Delhi     381644     342811    6470
# 7                                     Kerala     425123     332994    1458
# 8                                West Bengal     369671     325888    6784
# 9                                     Odisha     290116     273838    1373
# 10                                 Telangana     238632     218887    1336
# ...
