# %%
import pandas as pd 
pd.set_option('display.max_column',34)
Pop_Index=pd.read_csv(r'C:\Users\saurabh\Documents\Desktop\Data Science projects\Data For Projects\Covid-19.csv')
Pop_Index=Pop_Index[Pop_Index['date']=='2020-06-30']
Pop_Index
# Out:
#        iso_code continent        location        date  total_cases  new_cases  \
# 172         AFG      Asia     Afghanistan  2020-06-30      31238.0      271.0
# 286         ALB    Europe         Albania  2020-06-30       2466.0       64.0
# 464         DZA    Africa         Algeria  2020-06-30      13571.0      298.0
# 573         AND    Europe         Andorra  2020-06-30        855.0        0.0
# 674         AGO    Africa          Angola  2020-06-30        276.0        9.0
# ...         ...       ...             ...         ...          ...        ...
# 26633       ESH    Africa  Western Sahara  2020-06-30        208.0        0.0
# 26715       YEM      Asia           Yemen  2020-06-30       1128.0       10.0
# 26819       ZMB    Africa          Zambia  2020-06-30       1568.0       11.0
# 26921       ZWE    Africa        Zimbabwe  2020-06-30        574.0        7.0
# 27104  OWID_WRL       NaN           World  2020-06-30   10273001.0   160047.0
#
# ...

# %%
Pop_Index=Pop_Index[['continent','location','population','population_density','median_age','aged_65_older'	,'gdp_per_capita','extreme_poverty','female_smokers','male_smokers','life_expectancy']]
Pop_Index.set_index('location',inplace=True)

# %%
Pop_Index
# Out:
#                continent    population  population_density  median_age  \
# location
# Afghanistan         Asia  3.892834e+07              54.422        18.6
# Albania           Europe  2.877800e+06             104.871        38.0
# Algeria           Africa  4.385104e+07              17.348        29.1
# Andorra           Europe  7.726500e+04             163.755         NaN
# Angola            Africa  3.286627e+07              23.890        16.8
# ...                  ...           ...                 ...         ...
# Western Sahara    Africa  5.973300e+05                 NaN        28.4
# Yemen               Asia  2.982597e+07              53.508        20.3
# Zambia            Africa  1.838396e+07              22.995        17.7
# Zimbabwe          Africa  1.486293e+07              42.729        19.6
# World                NaN  7.794799e+09              58.045        30.9
#
#                 aged_65_older  gdp_per_capita  extreme_poverty  \
# location
# ...
